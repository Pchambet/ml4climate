# %% [markdown]
# # Appendix: Elements of Probability Theory (Pavliotis 2014)

# %% [markdown]
# ## Probability Measures

# %% [markdown]
# <hr>
#
# **Sample Space**
# <br>
# The set of all possible outcomes of an experiment is called the *sample space* and is denoted by $\Omega$.
#
# $Events$ are defined as subsets of the sample space.
# <hr>

# %% [markdown]
# <hr>
#
# **$\sigma$-algebra**
# <br>
# A collection $\mathcal{F}$ of sets in $\Omega$ is called a *$\sigma$-algebra* on $\Omega$ if
#
# 1. $\emptyset \in \mathcal{F}$;
# 2. if $A \in \mathcal{F}$, then $A^c \in \mathcal{F}$;
# 3. if $A_1, A_2, \ldots \in \mathcal{F}$, then $\cup_{i = 1}^\infty A_i \in \mathcal{F}$.
#
# <hr>

# %% [markdown]
# <hr>
#
# **Borel $\sigma$-algebra**
# <br>
# Let $\Omega = \mathbb{R}^p$. The $\sigma$-algebra generated by the open subsets of $\mathbb{R}^p$ is called the *Borel $\sigma$-algebra* of $\mathbb{R}^p$ and is denoted by $\mathcal{B}(\mathbb{R}^p)$.
#
# <hr>

# %% [markdown]
# The $\sigma$-algebra of a sample space contains all possible outcomes of the experiment that we want to study.
#
# Intuitively, the $\sigma$-algebra contains all the useful information that is available about the random experiment that we are performing.

# %% [markdown]
# <hr>
#
# **Probability Measure**
# <br>
# A probability measure $\mathbb{P}$ on the measurable space $(\Omega, \mathcal{F})$ is a function $\mathbb{P}: \mathcal{F} \to [0, 1]$ satisfying
#
# 1. $\mathbb{P}(\emptyset) = 0$, $\mathbb{P}(\Omega) = 1$;
# 2. For $A_1, A_2, \ldots$ with $A_i \cap A_j = \emptyset$, $i \ne  j$, then
#
# \begin{equation}
# \mathbb{P}(\cup_{i = 1}^\infty A_i) = \sum_{i = 1}^\infty \mathbb{P}(A_i)
# \end{equation}
#
# <hr>

# %% [markdown]
# <hr>
#
# **Probability Space**
# <br>
# The triple $(\Omega, \mathcal{F}, \mathbb{P})$ comprising a set $\Omega$, a $\sigma$-algebra $\mathcal{F}$ of subsets of $\Omega$ and a probability measure $\mathbb{P}$ on $(\Omega, \mathcal{F})$ is called a *probability space*.
#
# <hr>

# %% [markdown]
# The sets $A$ and $B$ are $independent$ if
#
# \begin{equation}
# \mathbb{P}(A \cap B) = \mathbb{P}(A) \mathbb{P}(B).
# \end{equation}

# %% [markdown]
# ## Random Variables

# %% [markdown]
# <hr>
#
# **Measurable Space**
# <br>
# A sample space $\Omega$ equipped with a $\sigma$-algebra of subsets $\mathcal{F}$ is called a *measurable space*.
#
# <hr>

# %% [markdown]
# <hr>
#
# **Random Variable**
# <br>
# Let $(\Omega, \mathcal{F})$ and $(\mathbb{R}^p, \mathcal{B}(\mathbb{R}^p))$ be two measurable spaces.
# A function $X: \Omega \to \mathbb{R}^p$ such that the event
#
# \begin{equation}
# \{\omega \in \Omega: X(\omega) \le \boldsymbol{x}\} =: \{X \le \boldsymbol{x}\}
# \end{equation}
#
# belongs to $\mathcal{F}$ for any $\boldsymbol{x} \in \mathbb{R}^p$ is called a *measurable function* or *random variable*.
#
# <hr>

# %% [markdown]
# <hr>
#
# **Distribution Function of a Random Variable**
# <br>
# Every random variable from a probability space $(\Omega, \mathcal{F}, \mathbb{P})$ to a measurable space $(\mathbb{R}^p, \mathcal{B}(\mathbb{R}^p))$ induces a probability measure on $\mathbb{R}^p$ that we identify with the *distribution function* $F_X: \mathbb{R}^p \to [0, 1]$ defined as
#
# \begin{equation}
# F_X(\boldsymbol{x}) = \mathbb{P}(X \le \boldsymbol{x}) = \mathbb{P}(\omega \in \Omega; X(\omega) \le \boldsymbol{x}), \boldsymbol{x} \in \mathcal{B}(\mathbb{R}^p).
# \end{equation}
#
# <hr>

# %% [markdown]
# <hr>
#
# **Expectation of Random Variables**
# <br>
# Let $X$ be a random variable from $(\Omega, \mathcal{F}, \mu)$ to $(\mathbb{R}^p, \mathcal{B}(\mathbb{R}^p))$.
# We define the *expectation* of $X$ by
#
# \begin{equation}
# \mathbb{E}(X) = \int_{\mathbb{R}^p} \boldsymbol{x} dF_X(\boldsymbol{x}).
# \end{equation}
#
# More generally, let $f: \mathbb{R}^p \to \mathbb{R}$ be measurable.
# Then
#
# \begin{equation}
# \mathbb{E}(f(X)) = \int_{\mathbb{R}^p} f(\boldsymbol{x}) dF_X(\boldsymbol{x}).
# \end{equation}
#
# <hr>

# %% [markdown]
# <hr>
#
# **$L^p$ spaces**
# <br>
# By $L^p(\Omega, \mathcal{F}, \mathbb{P})$ we mean the Banach space of measurable functions on $\Omega$ with norm
#
# \begin{equation}
# \|X\|_{L^p} = \left(E(|X|^p)\right)^{1/p}.
# \end{equation}
#
# <hr>

# %% [markdown]
# <hr>
#
# **Covariance, Variance and Correlation of Two Random Variables**
# <br>
# We define the *covariance* of two random variables $X$ and $Y$ as
#
# \begin{equation}
# \mathrm{cov}(X, Y) := \mathbb{E}((X - \mathbb{E}(X)) (Y - \mathbb{E}(Y)))
# = \mathbb{E}(X Y) - \mathbb{E}(X) \mathbb{E}(Y).
# \end{equation}
#
# The *variance* of $X$ is simply
#
# \begin{equation}
# \mathrm{var}(X) := \mathrm{cov}(X, X).
# \end{equation}
#
# The *correlation* of $X$ and $Y$ is
#
# \begin{equation}
# \mathrm{corr}(X, Y) := \frac{\mathrm{cov}(X, Y)}{\sqrt{\mathrm{var}(X)} \sqrt{\mathrm{var}(Y)}}.
# \end{equation}
#
# <hr>

# %% [markdown]
# ## Conditional Expectation

# %% [markdown]
# <hr>
#
# **Conditional Probability**
# <br>
# The *conditional probability* of $A$ knowing $B$ is
#
# \begin{equation}
# \mathbb{P}(A | B) := \frac{\mathbb{P}(A \cap B)}{\mathbb{P}(B)}.
# \end{equation}
#
# For random variables, the *conditional probability* of $X$ knowing $Y$ is
#
# \begin{equation}
# \mathbb{P}(X | Y) := \frac{\mathbb{P}(X \cap Y)}{\mathbb{P}(Y)}.
# \end{equation}
#
# <hr>

# %% [markdown]
# <hr>
#
# **Conditional Expectation**
# <br>
# Assume that $X \in L^1(\Omega, \mathcal{F}, \mathbb{P})$ and let $\mathcal{G}$ be a sub-$\sigma$-algebra of $\mathcal{F}$.
# The *conditional expectation* of $X$ with respect to $\mathcal{G}$ is defined to be the function $\mathbb{E}(X | \mathcal{G}): \Omega \to \mathbb{R}^p$, which is $\mathcal{G}$-measurable and satisfies
#
# \begin{equation}
# \int_G \mathbb{E}(X | \mathcal{G}) d\mathbb{P} = \int_G X d\mathbb{P},
# \end{equation}
#
# for all $G \in \mathcal{G}.$
#
# <hr>

# %% [markdown]
# Given $\mathcal{G} \subset \mathcal{F}$, we define the conditional distribution function $F_X(\boldsymbol{x} | \mathcal{G}) = \mathbb{P}(X \le \boldsymbol{x} | \mathcal{G})$ for $\boldsymbol{x} \in \mathbb{R}^p$.
# Assume that $f: \mathbb{R}^p \to \mathbb{R}$ is such that $\mathbb{E}(f(X)) < \infty$.
# Then
#
# \begin{equation}
# E(f(X) | \mathcal{G}) = \int_{\mathbb{R}^p} f(\boldsymbol{x}) dF_X(\boldsymbol{x} | \mathcal{G}).
# \end{equation}

# %% [markdown]
# ## References
#
# - [Pavliotis, G.A., 2014. *Stochastic Processes and Applications*. Springer, New York.](https://doi.org/10.1007/978-1-4939-1323-7)

# %% [markdown]
# ***
# ## Credit
#
# [//]: # "This notebook is part of [E4C Interdisciplinary Center - Education](https://gitlab.in2p3.fr/energy4climate/public/education)."
# Contributors include Bruno Deremble and Alexis Tantet.
#
# <br>
#
# <div style="display: flex; height: 70px">
#
# <img alt="Logo LMD" src="images/logos/logo_lmd.jpg" style="display: inline-block"/>
#
# <img alt="Logo IPSL" src="images/logos/logo_ipsl.png" style="display: inline-block"/>
#
# <img alt="Logo E4C" src="images/logos/logo_e4c_final.png" style="display: inline-block"/>
#
# <img alt="Logo EP" src="images/logos/logo_ep.png" style="display: inline-block"/>
#
# <img alt="Logo SU" src="images/logos/logo_su.png" style="display: inline-block"/>
#
# <img alt="Logo ENS" src="images/logos/logo_ens.jpg" style="display: inline-block"/>
#
# <img alt="Logo CNRS" src="images/logos/logo_cnrs.png" style="display: inline-block"/>
#
# </div>
#
# <hr>
#
# <div style="display: flex">
#     <a rel="license" href="http://creativecommons.org/licenses/by-sa/4.0/"><img alt="Creative Commons License" style="border-width:0; margin-right: 10px" src="https://i.creativecommons.org/l/by-sa/4.0/88x31.png" /></a>
#     <br>This work is licensed under a &nbsp; <a rel="license" href="http://creativecommons.org/licenses/by-sa/4.0/">Creative Commons Attribution-ShareAlike 4.0 International License</a>.
# </div>
